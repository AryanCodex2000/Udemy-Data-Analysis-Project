# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ud = pd.read_csv(r"udemy.csv")

# %%
ud.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %% [markdown]
# Subjects for which udemy is providing the courses.

# %%
ud.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# which subjects has the maximum number of courses.

# %%
ud.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %% [markdown]
# show all the courses which are free of cost.

# %%
ud.is_paid == False
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680     True
# 3681    False
# Name: is_paid, Length: 3682, dtype: bool

# %%
ud[ud.is_paid == False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %% [markdown]
# Show now the corses which are paid.

# %%
ud.is_paid == True
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3677     True
# 3678     True
# 3679     True
# 3680    False
# 3681     True
# Name: is_paid, Length: 3682, dtype: bool

# %%
ud[ud.is_paid == True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# Which are the top selling courses.

# %%
ud.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
ud.sort_values('num_subscribers', ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 1390    1136038          Free Ways to Create Passive Income Online     True
# 1909    1157298  Introduction to Forex Trading Business For Beg...     True
# 1910    1157298  Introduction to Forex Trading Business For Beg...     True
# 1325    1187084  Forex how traders beat the markest with little...     True
# 44      1231958        60 Minutes to Fundamental Accounting Skills     True
#
# ...

# %% [markdown]
# Which are the least selling courses.

# %%
ud.sort_values('num_subscribers', ascending=True)
# Out:
#       course_id                                       course_title  is_paid  \
# 98      1219820  Accounting - The 6 most important rules you mu...     True
# 2350     371900  Learn to create Text fire effect in Adobe Phot...     True
# 3221    1057040                           Teeter-Totter Accounting     True
# 649     1233314                      Building a Balanced Scorecard     True
# 954     1169196  Credit concepts and checklist for bankers, cre...     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %%
ud.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  is_paid  \
# 98      1219820  Accounting - The 6 most important rules you mu...     True
# 2350     371900  Learn to create Text fire effect in Adobe Phot...     True
# 3221    1057040                           Teeter-Totter Accounting     True
# 649     1233314                      Building a Balanced Scorecard     True
# 954     1169196  Credit concepts and checklist for bankers, cre...     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %% [markdown]
# show all courses of graphic design where the price is below 100?

# %%
ud[(ud.subject == 'Graphic Design') & (ud.price <= '100')]
# Out:
#       course_id                                       course_title  is_paid  \
# 47      1269190          7 Secrets To Designing In Black and White     True
# 169      983444       Adobe Illustrator Vectors For Hand Letterers     True
# 184      638040  Adobe Photoshop Essentials: Master Adobe Photo...     True
# 520      978462              Blender Modelling Series - Volume Two     True
# 699      757900                          Canva : Book Cover Design     True
# 1029    1160004                 Design a logo for FREE in Inkscape     True
# 1071    1161864  Diseño impreso - Preimpresión para offset en I...     True
# 1444     490392                Getting Started with Illustrator CC     True
# 1568     727510             How To Become An Etsy Wholesale Seller     True
# 1616     996868          How to Design a Logo in Adobe Illustrator     True
# 1697     654038              How To Sell Your Art Online With ETSY     True
# ...

# %% [markdown]
# show all the course below 500

# %%
ud[(ud.subject == 'Graphic Design') & (ud.price < '500')]
# Out:
#       course_id                                       course_title  is_paid  \
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20      1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35      1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39       599652                     48 Logo Designs and Techniques     True
# 47      1269190          7 Secrets To Designing In Black and White     True
# ...         ...                                                ...      ...
# 3588    1131780  Whiteboard Animation, Beginner To Expert - In ...     True
# 3594     908664  Word Swag : Create Stunning Images with the Wo...     True
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %% [markdown]
# List  out all the courses related with python.

# %%
ud[ud.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
len(ud[ud.course_title.str.contains('Python')])
# Out:
# 29

# %% [markdown]
# What are the courses which are published in the year 2015.

# %%
ud.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
ud['published_timestamp'] = pd.to_datetime(ud.published_timestamp)

# %%
ud.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
ud.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration       published_timestamp              subject
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments

# %%
ud['Year'] = ud['published_timestamp'].dt.year

# %%
ud
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
ud[ud.Year == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# what are the courses published in 2014.

# %%
ud[ud.Year == 2014]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 15       145220                  1. Principles of Simple Interest      True
# 17       157336                        10.  Bonds and Bond Pricing     True
# 21       315716         15 Mandamientos para ganar dinero en Bolsa     True
# ...         ...                                                ...      ...
# 3637     361620                              Wordpress Tutorial        True
# 3643     326948  Working Capital Management for CA / CFA / CPA ...     True
# 3644     221872       Working Capital Management for Entrepreneurs     True
# 3669     180384                               Yield Curve Dynamics     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
#
# ...

# %% [markdown]
# what are the courses published in the year 2014 and 2015.

# %%
ud[(ud.Year == 2014) | (ud.Year == 2015)]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 15       145220                  1. Principles of Simple Interest      True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# courses published in the year 2012 and 2013

# %%
ud[(ud.Year == 2012) | (ud.Year == 2013)]
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# 14        72262                                      1 hour jQuery     True
# 28        54246  3 documentos clave para administrar tu empresa...     True
# ...         ...                                                ...      ...
# 3582      45136  Weekly Options and study of Options expiration...     True
# 3593     100526                     Winning Options Trading System     True
# 3647      40495  World's Fastest Piano Method - The Piano Revol...     True
# 3653     113888  Writing CSS with {LESS} - Tutorial From Infini...     True
# 3673      79364                       Your Business by the Numbers     True
#
# ...

# %% [markdown]
# Courses started in 2013 to 2015

# %%
ud[(ud.Year == 2013) | (ud.Year == 2014) | (ud.Year == 2015)]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# What are the Max. Number of Subscribers for each Level of courses.

# %%
ud.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
ud.groupby('level')

# %%
ud.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %% [markdown]
# the maximum values are shown same wise we can show the minimum values.

# %%
ud.groupby('level')['num_subscribers'].min()
# Out:
# level
# All Levels            0
# Beginner Level        0
# Expert Level          1
# Intermediate Level    0
# Name: num_subscribers, dtype: int64

# %%
ud.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels             True  Free           268923        27445           544
# Beginner Level         True  Free           161029         5924           779
# Expert Level           True    95             5172          249           157
# Intermediate Level     True  Free            29167         3326           320
#
# ...

# %%
ud.groupby('level').min()
# Out:
#                     course_id  \
# level
# All Levels               8324
# Beginner Level          12975
# Expert Level            42640
# Intermediate Level      17887
#
#                                                          course_title  \
# level
# All Levels          #1 Piano Hand Coordination: Play 10th Ballad i...
# Beginner Level      1 - Concepts of Statistics For Beginners Step ...
# Expert Level                               Adobe InDesign CC Advanced
# Intermediate Level  #10 Hand Coordination - Transfer Chord Ballad ...
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels            False   100                0            0             0
# Beginner Level        False   100                0            0             0
# Expert Level           True   100                1            0             6
# Intermediate Level    False   100                0            0             5
#
# ...
